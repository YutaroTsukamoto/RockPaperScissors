# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC
import numpy as np

# %%
data = pd.read_csv("coordinates_normalized.csv", header=None)
label = data.iloc[:, 0]
X = data.iloc[:, 1:]
# Out:
#     1    2    3         4   ...        60        61        62        63
# 0  0.0  0.0  0.0  0.254032  ...  0.193285  0.181910  0.211837  0.197853
# 1  0.0  0.0  0.0 -0.210576  ...  0.351303 -0.222478  0.232805  0.333090
# 2  0.0  0.0  0.0 -0.158714  ...  0.575090  0.010338  0.445257  0.472341
# 3  0.0  0.0  0.0 -0.339396  ...  0.568516 -0.288350  0.288500  0.534917
# 4  0.0  0.0  0.0 -0.238423  ...  0.218660 -0.269697  0.324998  0.259723
#
# [5 rows x 63 columns]

# %%
model = SVC()
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = []

for train_index, test_index in skf.split(X, label):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = label.iloc[train_index], label.iloc[test_index]
    
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    scores.append(score)

print(f"各foldのスコア: {scores}")
print(f"平均スコア: {np.mean(scores):.4f}")
print(f"標準偏差: {np.std(scores):.4f}")
# Out:
# 各foldのスコア: [0.9877450980392157, 0.9901719901719902, 0.995085995085995, 0.9754299754299754, 0.9754299754299754]
# 平均スコア: 0.9848
# 標準偏差: 0.0080

# %%
import pickle

model = SVC()

model.fit(X,label)

with open("svm_model.pkl", "wb") as f:
    pickle.dump(model, f)
